# %% [markdown]
# # <font color="blue"> MBA em Ciência de Dados</font>
# # <font color="blue">Programação para Ciência de Dados</font>
#
# ## <font color="blue">Pandas Parte I - Avaliação</font>
# **Material Produzido por Luis Gustavo Nonato**<br>
# **Cemeai - ICMC/USP São Carlos**
# ---

# %% [markdown]
# As questões a seguir farão uso do arquivo <font style="font-family: monaco">WorldCupMatches.csv</font>, disponível para download no moodle. Baixe o arquivo no seu diretório de trabalho para responder as questões.
#
# O arquivo <font style="font-family: monaco">WorldCupMatches.csv</font> contém informações sobre todas as partidas de copas do mundo entre 1930 e 2014, ou seja, cada linha no arquivo corresponde a uma partida de futebol em copa do mundo.
#
# Algumas das colunas que serão importantes para resolver as questões são:
# - __Year__: indica o ano da copa
# - __Stage__: em qual fase da copa a partida aconteceu
# - __HomeTeamName__: nome do time anfitrião da partida
# - __AwayTeamName__: nome do time adversário na partida
# - __Attendance__: número de espectadores da partida
# - __Stadium__: estádio onde a partida foi realizada
# - __HalfTimeHomeGoals__: número de gols do time anfitrião no primeiro tempo
# - __HalfTimeAwayGoals__: número de gols do time adversário no primeiro tempo

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Exercício 1)
# Leia o arquivo <font style="font-family: monaco">WorldCupMatches.csv</font>, armazene em uma variável DataFrame  chamada `copa_partidas`. Quantas linhas correspondendo a instâncias de dados e quantas colunas o DataFrame possui?
#
# a) 117, 21<br>
# b) 518, 18<br>
# c) 720, 31<br>
# d) 836, 20

# %%
# Solucao
df = pd.read_csv('WorldCupMatches.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               836 non-null    int64
#  1   Datetime           836 non-null    object
#  2   Stage              836 non-null    object
#  3   Stadium            836 non-null    object
#  4   City               836 non-null    object
#  5   HomeTeamName       836 non-null    object
#  6   HomeTeamGoals      836 non-null    int64
#  7   AwayTeamGoals      836 non-null    int64
#  8   AwayTeamName       836 non-null    object
#  9   WinConditions      836 non-null    object
#  10  Attendance         836 non-null    float64
#  11  HalfTimeHomeGoals  836 non-null    int64
#  12  HalfTimeAwayGoals  836 non-null    int64
#  13  Referee            836 non-null    object
#  14  Assistant1         836 non-null    object
#  15  Assistant2         836 non-null    object
#  16  RoundID            836 non-null    int64
#  17  MatchID            836 non-null    int64
#  18  HomeTeamInitials   836 non-null    object
#  19  AwayTeamInitials   836 non-null    object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 130.8+ KB

# %% [markdown]
# ### Exercício 2)
# O comando abaixo extrai quais são as 'strings' contidas na coluna `Stage`:
# ```python
# copa_partidas['Stage'].unique()
# ```
# Dentre as strings resultantes, 'Semi-finals' indica que a linha corresponde a uma partida de semi-final de uma copa.
#
# Utilizando o método <font color='blue'>query</font>, encontre as linhas contendo as partidas de semi-final das copas. Construa uma lista contendo os nomes dos times que disputaram a semi-final da copa de 1990.
#
# Os nomes que aparecem na lista construída são:
#
# a) ['France', 'Argentina', 'Germany FR', 'Belgium']<br>
# b) ['Italy', 'Argentina', 'Germany FR', 'Belgica']<br>
# c) ['Italy', 'Germany FR', 'Argentina', 'England']<br>
# c) ['France', 'Argentina', 'Brazil', 'Belgium']<br>
#
# __DICA:__ Utilize o método <font color='blue'>query</font> duas vezes, a primeira para obter um DataFrame com os semi-finalistas e a segunda para obter um DataFrame com os semi-finalistas da copa de 1990. Os nomes dos semi-finalistas estão nas colunas `HomeTeamNam` e `AwayTeamName`.

# %%
# SOLUÇÃO
df[(df['Stage'] == 'Semi-finals') & (df['Year'] == 1990)]
# Out:
#      Year              Datetime        Stage            Stadium     City  \
# 460  1990  03 Jul 1990 - 20:00   Semi-finals          San Paolo  Naples
# 461  1990  04 Jul 1990 - 20:00   Semi-finals  Stadio delle Alpi   Turin
#
#     HomeTeamName  HomeTeamGoals  AwayTeamGoals AwayTeamName  \
# 460        Italy              1              1    Argentina
# 461   Germany FR              1              1      England
#
#                   WinConditions  Attendance  HalfTimeHomeGoals  \
# 460   win on penalties (3 - 4)      59978.0                  0
# 461   win on penalties (4 - 3)      62628.0                  0
#
#      HalfTimeAwayGoals                  Referee                Assistant1  \
# 460                  0     VAUTROT Michel (FRA)  LISTKIEWICZ Michal (POL)
# 461                  0  RAMIZ WRIGHT Jose (BRA)        QUINIOU Joel (FRA)
#
#                     Assistant2  RoundID  MatchID HomeTeamInitials  \
# 460      MIKKELSEN Peter (DEN)     3464       28              ITA
# 461  PEREZ HOYOS Armando (COL)     3464      159              FRG
#
#     AwayTeamInitials
# 460              ARG
# 461              ENG

# %% [markdown]
# ### Exercício 3)
# Quantas vezes o Brasil jogou contra a Argentina em copas do mundo?
#
# a) 7<br>
# b) 6<br>
# c) 5<br>
# d) 4
#
# __Dica:__ Utilize o método <font color='blue'>query</font> combinando <font color='blue'>&</font> (AND) e <font color='blue'>|</font> (OR)

# %%
# SOLUÇÃO
df[((df['HomeTeamName'] == 'Brazil') & (df['AwayTeamName'] == 'Argentina')) | (df['HomeTeamName'] == 'Argentina') & (df['AwayTeamName'] == 'Brazil')]
# Out:
#      Year              Datetime        Stage  \
# 260  1974  30 Jun 1974 - 16:00       Group A
# 301  1978  18 Jun 1978 - 19:15       Group B
# 350  1982  02 Jul 1982 - 17:15       Group 3
# 450  1990  24 Jun 1990 - 17:00   Round of 16
#
#                                          Stadium        City HomeTeamName  \
# 260                         Niedersachsenstadion    Hanover     Argentina
# 301  Arroyito - Estadio Dr. Lisandro de la Torre    Rosario     Argentina
# 350                                       Sarria  Barcelona     Argentina
# 450                            Stadio delle Alpi      Turin        Brazil
#
#      HomeTeamGoals  AwayTeamGoals AwayTeamName WinConditions  Attendance  \
# 260              1              2       Brazil                   39400.0
# 301              0              0       Brazil                   37326.0
# 350              1              3       Brazil                   44000.0
# 450              0              1    Argentina                   61381.0
#
#      HalfTimeHomeGoals  HalfTimeAwayGoals                    Referee  \
# 260                  1                  1         LORAUX Vital (BEL)
# 301                  0                  0       PALOTAI Karoly (HUN)
# 350                  0                  1  RUBIO VAZQUEZ Mario (MEX)
# 450                  0                  0         QUINIOU Joel (FRA)
#
#                             Assistant1                Assistant2  RoundID  \
# 260                NDIAYE Birame (SEN)         TAYLOR John (ENG)      263
# 301               LINEMAYR Erich (AUT)        PROKOP Adolf (GDR)      279
# 350  ARISTIZABAL MURCIA Gilberto (COL)       CASTRO Gaston (CHI)      294
# 450                SPIRIN Alexey (RUS)  PAIRETTO Pierluigi (ITA)      323
#
#      MatchID HomeTeamInitials AwayTeamInitials
# 260     1945              ARG              BRA
# 301     2196              ARG              BRA
# 350      750              ARG              BRA
# 450       25              BRA              ARG

# %% [markdown]
# ### Exercício 4)
# Qual foi a partida em copa do mundo com o maio número gols do time adversário no primeiro tempo?
#
# a) Mexico X Paraguay em 1986<br>
# b) Uruguay X Brazil em 1950<br>
# c) Brazil X Germany em 2014<br>
# d) Argentina X England em 1986
#
# __DICA:__ Ordene o DataFrame pela coluna `HalfTimeAwayGoals`

# %%
# SOLUÇÃO
df.sort_values(by='HalfTimeAwayGoals', ascending=False)
# Out:
#      Year              Datetime           Stage                   Stadium  \
# 246  1974  19 Jun 1974 - 19:30          Group 4            Olympiastadion
# 826  2014  08 Jul 2014 - 17:00      Semi-finals          Estadio Mineirao
# 94   1954  26 Jun 1954 - 17:00   Quarter-finals               La Pontaise
# 628  2002  15 Jun 2002 - 20:30      Round of 16  Niigata Stadium Big Swan
# 195  1966  23 Jul 1966 - 15:00   Quarter-finals             Goodison Park
# ..    ...                   ...             ...                       ...
# 341  1982  25 Jun 1982 - 17:15          Group 2                El Molinon
# 342  1982  25 Jun 1982 - 17:15          Group 4                 San Mames
# 343  1982  25 Jun 1982 - 21:00          Group 5             Luis Casanova
# 345  1982  28 Jun 1982 - 21:00          Group 1                  Camp Nou
# 835  2014  01 Jul 2014 - 17:00      Round of 16          Arena Fonte Nova
#
#                 City      HomeTeamName  HomeTeamGoals  AwayTeamGoals  \
# 246          Munich              Haiti              0              7
# 826  Belo Horizonte             Brazil              1              7
# 94         Lausanne            Austria              7              5
# 628         Niigata            Denmark              0              3
# 195       Liverpool           Portugal              5              3
# ..               ...               ...            ...            ...
# 341           Gijon         Germany FR              1              0
# 342          Bilbao            England              1              0
# 343        Valencia   Northern Ireland              1              0
# 345       Barcelona             Poland              3              0
# 835        Salvador            Belgium              2              1
#
#     AwayTeamName                  WinConditions  Attendance  \
# 246       Poland                                    25300.0
# 826      Germany                                    58141.0
# 94   Switzerland                                    35000.0
# 628      England                                    40582.0
# 195    Korea DPR                                    40248.0
# ..           ...                            ...         ...
# 341      Austria                                    41000.0
# 342       Kuwait                                    39700.0
# 343        Spain                                    49562.0
# 345      Belgium                                    65000.0
# 835          USA  Belgium win after extra time      51227.0
#
#      HalfTimeHomeGoals  HalfTimeAwayGoals                            Referee  \
# 246                  0                  5               SUPPIAH George (SIN)
# 826                  0                  5              RODRIGUEZ Marco (MEX)
# 94                   5                  4            FAULTLESS Charlie (SCO)
# 628                  0                  3                  MERK Markus (GER)
# 195                  2                  3           ASHKENAZI Menachem (ISR)
# ..                 ...                ...                                ...
# 341                  1                  0             VALENTINE Robert (SCO)
# 342                  1                  0  ARISTIZABAL MURCIA Gilberto (COL)
# 343                  0                  0                 ORTIZ Hector (PAR)
# 345                  2                  0          SILES Jesus Paulino (CRC)
# 835                  0                  0              HAIMOUDI Djamel (ALG)
#
#                       Assistant1                    Assistant2   RoundID  \
# 246      BIWERSI Ferdinand (GER)       ESCHWEILER Walter (GER)       262
# 826      TORRENTERA Marvin (MEX)         QUINTERO Marcos (MEX)    255955
# 94           ASENSI Manuel (ESP)          SCHMETZER Emil (FRG)       212
# 628         MUELLER Heiner (GER)             AMLER Evzen (CZE)  43950200
# 195            GALBA Karol (TCH)         SCHWINTE Pierre (FRA)       239
# ..                           ...                           ...       ...
# 341         AL DOY Ebrahim (BHR)          COELHO Arnaldo (BRA)       293
# 342  LUND-SORENSEN Henning (DEN)  GARCIA CARRION Jose L. (ESP)       293
# 343  LABO REVOREDO Enrique (PER)           PONNET Alexis (BEL)       293
# 345  LABO REVOREDO Enrique (PER)           CASTRO Gaston (CHI)       294
# 835         ACHIK Redouane (MAR)       ETCHIALI Abdelhak (ALG)    255951
#
#        MatchID HomeTeamInitials AwayTeamInitials
# 246       2085              HAI              POL
# 826  300186474              BRA              GER
# 94        1237              AUT              SUI
# 628   43950050              DEN              ENG
# 195       1702              POR              PRK
# ..         ...              ...              ...
# 341        770              FRG              AUT
# 342        882              ENG              KUW
# 343        902              NIR              ESP
# 345        782              POL              BEL
# 835  300186497              BEL              USA
#
# [836 rows x 20 columns]

# %% [markdown]
# ### Exercício 5)
# Qual foi o estádio com o maior número de partidas?
#
# a) Nacional<br>
# b) Jalisco<br>
# c) Maracana<br>
# d) Estadio Azteca
#
# __Dica:__ Construa um dicionário onde a chave é o nome do estádio e o valor o número de partidas disputadas naquele estádio. Busque pela tupla (chave,valor) onde o valor é máximo.

# %%
df.groupby(by='Stadium').count().sort_values(by='Year',ascending=False)
# Out:
#                          Year  Datetime  Stage  City  HomeTeamName  \
# Stadium
# Estadio Azteca             19        19     19    19            19
# Olympiastadion             14        14     14    14            14
# Jalisco                    14        14     14    14            14
# Nou Camp - Estadio Le�n    11        11     11    11            11
# Estadio Centenario         10        10     10    10            10
# ...                       ...       ...    ...   ...           ...
# Fort Carree                 1         1      1     1             1
# Stade de la Meinau          1         1      1     1             1
# Rimnersvallen               1         1      1     1             1
# White City                  1         1      1     1             1
# Friuli                      1         1      1     1             1
#
#                          HomeTeamGoals  AwayTeamGoals  AwayTeamName  \
# Stadium
# Estadio Azteca                      19             19            19
# Olympiastadion                      14             14            14
# Jalisco                             14             14            14
# Nou Camp - Estadio Le�n             11             11            11
# Estadio Centenario                  10             10            10
# ...                                ...            ...           ...
# Fort Carree                          1              1             1
# Stade de la Meinau                   1              1             1
# Rimnersvallen                        1              1             1
# White City                           1              1             1
# Friuli                               1              1             1
#
#                          WinConditions  Attendance  HalfTimeHomeGoals  \
# Stadium
# Estadio Azteca                      19          19                 19
# Olympiastadion                      14          14                 14
# Jalisco                             14          14                 14
# Nou Camp - Estadio Le�n             11          11                 11
# Estadio Centenario                  10          10                 10
# ...                                ...         ...                ...
# Fort Carree                          1           1                  1
# Stade de la Meinau                   1           1                  1
# Rimnersvallen                        1           1                  1
# White City                           1           1                  1
# Friuli                               1           1                  1
#
#                          HalfTimeAwayGoals  Referee  Assistant1  Assistant2  \
# Stadium
# Estadio Azteca                          19       19          19          19
# Olympiastadion                          14       14          14          14
# Jalisco                                 14       14          14          14
# Nou Camp - Estadio Le�n                 11       11          11          11
# Estadio Centenario                      10       10          10          10
# ...                                    ...      ...         ...         ...
# Fort Carree                              1        1           1           1
# Stade de la Meinau                       1        1           1           1
# Rimnersvallen                            1        1           1           1
# White City                               1        1           1           1
# Friuli                                   1        1           1           1
#
#                          RoundID  MatchID  HomeTeamInitials  AwayTeamInitials
# Stadium
# Estadio Azteca                19       19                19                19
# Olympiastadion                14       14                14                14
# Jalisco                       14       14                14                14
# Nou Camp - Estadio Le�n       11       11                11                11
# Estadio Centenario            10       10                10                10
# ...                          ...      ...               ...               ...
# Fort Carree                    1        1                 1                 1
# Stade de la Meinau             1        1                 1                 1
# Rimnersvallen                  1        1                 1                 1
# White City                     1        1                 1                 1
# Friuli                         1        1                 1                 1
#
# [181 rows x 19 columns]
